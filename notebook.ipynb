# %% [markdown]
# ---
# title: "Rendered JupyteR"
# author: "Jay DesLauriers"
# format: pdf
# ---
# \newpage
# \tableofcontents

# %% [markdown]
# # Arithmetic

# %%
2 + 2
3 + 2
5 + 2
# Out:
# [1] 4
# [1] 5
# [1] 7

# %% [markdown]
# # Try it out
#
# Run the cell below.

# %%
library(ggplot2)
ggplot(mtcars, aes(x = wt, y = mpg)) +
  geom_point() +
  theme_minimal() +
  labs(title = "Car Weight vs MPG",
       x = "Weight (1000 lbs)",
       y = "Miles per Gallon")
# Out:
# plot without title

# %% [markdown]
# From the command-line, run `quarto render notebook.ipynb --to pdf` to render this.
